# %%
from manim import *
config.media_width = "100%"
# Out:
# Manim Community v0.15.2

# %%
class Example(Scene):
    def construct(self):
        self.add(Dot())

# %manim -s Example
# Out:
# [05/11/22 13:21:10] INFO                                             ]8;id=328319;file:///Users/alexandervazquez/GitHubProjects/mce-inter/docs/jmce/lib/python3.9/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=724329;file:///Users/alexandervazquez/GitHubProjects/mce-inter/docs/jmce/lib/python3.9/site-packages/manim/scene/scene_file_writer.py#718\718]8;;\
#                              File ready at '/Users/alexandervazquez/
#                              GitHubProjects/mce-inter/docs/nb_tests/
#                              media/images/nb_tests/Example_ManimCE_v
#                              0.15.2.png'
# ...
